# %%
from ai_engine import classify_complaint
print(classify_complaint("Street light is sparking"))
# Out:
# {'text': 'Street light is sparking', 'predicted_category': 'Electrical', 'confidence': 0.9751366376876831, 'all_scores': {'Electrical': 0.9751366376876831, 'Plumbing': 0.01040191762149334, 'Waste Management': 0.009055313654243946, 'Toxic Waste': 0.00540609285235405}}
